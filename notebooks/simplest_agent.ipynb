# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# 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
# 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
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name = "Nutrition Agent",
    instructions= """
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Agent", ...)
# - Final output (str):
#     Bananas are generally healthy as part of a balanced diet.
#
#     Key benefits:
#     - Good source of potassium (supports blood pressure and heart function)
#     - Dietary fiber (aids digestion)
#     - Vitamin B6 and vitamin C
#     - Quick, portable energy (natural sugars + carbs)
#
#     Nutrients (approx. for 1 medium banana):
#     - About 105 calories
#     - ~27 g carbs, ~3 g fiber, ~14 g sugar
#     - ~422 mg potassium
#     - ~0.3 g fat
#
#     Things to consider:
#     - If you have kidney disease or restricted potassium, watch portion size.
#     - Pair with protein or fat to stabilize blood sugar.
#
#     Want a specific daily portion based on your goals?
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Mostly healthy. Key points:
#
# - Good nutrients: potassium, vitamin C, vitamin B6, fiber, quick energy.
# - Low in fat and calories per fruit.
# - Ripeness affects sugar: greower = more resistant starch; riper = more simple sugars.
# - Benefits: supports heart and digestion; convenient snack.
# - Considerations: portion size if diabetes or kidney disease (potassium restriction).
# - Typical guidance: 1–2 medium bananas daily fits a balanced diet.
#
# If you have specific conditions, I can tailor advice.

# %% [markdown]
# _Good Job!_
